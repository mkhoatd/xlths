# %%
# read file by librosa
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from __future__ import annotations

# read audio.mp4a
y: np.ndarray  # âm thanh
sr: int  # tần số lấy mẫu
(y, sr)=librosa.load('b.m4a')
M=100
new_y=np.array([y[i] for i in range(0, len(y), M)]) #new_y[2]=y[2M]
y[0:20], new_y[0:20]
# Out:
# (array([-3.9538067e-05, -7.4487085e-05, -3.5668189e-05, -8.6259774e-05,
#         -5.8851183e-05, -6.6113804e-05, -5.4290718e-05, -6.9451038e-05,
#         -7.7367331e-05, -3.2619937e-05, -4.6678797e-06,  7.1565686e-05,
#          4.9355676e-05,  1.0093734e-04,  9.4426381e-05,  4.6521594e-04,
#          3.5246502e-04, -4.4053292e-04, -8.3389820e-04, -7.9169421e-04],
#        dtype=float32),
#  array([-3.9538067e-05, -2.0002991e-04,  3.9034837e-03,  4.5443336e-03,
#          2.2612542e-02,  1.1625936e-02, -5.2128769e-02,  6.0388651e-02,
#         -5.2785710e-02,  8.3045818e-02,  5.6254468e-03, -3.5382681e-02,
#         -1.8322770e-02,  5.3710364e-02, -8.4125631e-02, -7.7464697e-03,
#          4.4437435e-02, -1.1891247e-02, -3.3187337e-02, -1.3272610e-01],
#        dtype=float32))

# %%
len(new_y), sr//M
# Out:
# (598, 220)

# %%
len(y)/sr
# Out:
# 2.708027210884354

# %%
len(y)
# Out:
# 59712

# %%
import sounddevice as sd

# %%
sd.play(y, sr)

# %%
sd.play(new_y, sr//M)
# Out:
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# /Users/mkhoatd/Developer/xlths/nen.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mkhoatd/Developer/xlths/nen.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> sd.play(new_y, sr//M)
#
# File /usr/local/Caskroom/mambaforge/base/envs/torch/lib/python3.8/site-packages/sounddevice.py:174, in play(data, samplerate, mapping, blocking, loop, **kwargs)
#     171     ctx.write_outdata(outdata)
#     172     ctx.callback_exit()
# --> 174 ctx.start_stream(OutputStream, samplerate, ctx.output_channels,
#     175                  ctx.output_dtype, callback, blocking,
#     176                  prime_output_buffers_using_stream_callback=False,
#     177                  **kwargs)
#
# File /usr/local/Caskroom/mambaforge/base/envs/torch/lib/python3.8/site-packages/sounddevice.py:2573, in _CallbackContext.start_stream(self, StreamClass, samplerate, channels, dtype, callback, blocking, **kwargs)
#    2570 def start_stream(self, StreamClass, samplerate, channels, dtype, callback,
#    2571                  blocking, **kwargs):
#    2572     stop()  # Stop previous playback/recording
# -> 2573     self.stream = StreamClass(samplerate=samplerate,
#    2574                               channels=channels,
#    2575                               dtype=dtype,
#    2576                               callback=callback,
#    2577                               finished_callback=self.finished_callback,
#    2578                               **kwargs)
#    2579     self.stream.start()
#    2580     global _last_callback
#
# File /usr/local/Caskroom/mambaforge/base/envs/torch/lib/python3.8/site-packages/sounddevice.py:1488, in OutputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1458 def __init__(self, samplerate=None, blocksize=None,
#    1459              device=None, channels=None, dtype=None, latency=None,
#    1460              extra_settings=None, callback=None, finished_callback=None,
#    1461              clip_off=None, dither_off=None, never_drop_input=None,
#    1462              prime_output_buffers_using_stream_callback=None):
#    1463     """PortAudio output stream (using NumPy).
#    1464
#    1465     This has the same methods and attributes as `Stream`, except
#    (...)
#    1486
#    1487     """
# -> 1488     _StreamBase.__init__(self, kind='output', wrap_callback='array',
#    1489                          **_remove_self(locals()))
#
# File /usr/local/Caskroom/mambaforge/base/envs/torch/lib/python3.8/site-packages/sounddevice.py:892, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     890     userdata = _ffi.NULL
#     891 self._ptr = _ffi.new('PaStream**')
# --> 892 _check(_lib.Pa_OpenStream(self._ptr, iparameters, oparameters,
#     893                           samplerate, blocksize, stream_flags,
#     894                           callback_ptr, userdata),
#     895        'Error opening {}'.format(self.__class__.__name__))
#     897 # dereference PaStream** --> PaStream*
#     898 self._ptr = self._ptr[0]
#
# File /usr/local/Caskroom/mambaforge/base/envs/torch/lib/python3.8/site-packages/sounddevice.py:2738, in _check(err, msg)
#    2735     hosterror_info = host_api, info.errorCode, hosterror_text
#    2736     raise PortAudioError(errormsg, err, hosterror_info)
# -> 2738 raise PortAudioError(errormsg, err)
#
# PortAudioError: Error opening OutputStream: Invalid sample rate [PaErrorCode -9997]

# %%
fig, (ax0, ax1)=plt.subplots(nrows=1,
                       ncols=2,
                       figsize=(14, 5))
librosa.display.waveshow(y, sr=sr, ax=ax0)
librosa.display.waveshow(new_y, sr=sr//M, ax=ax1)
plt.show()
